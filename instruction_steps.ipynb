# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Wed_Jun__9_20:32:38_PDT_2021
# Cuda compilation tools, release 11.3, V11.3.122
# Build cuda_11.3.r11.3/compiler.30059648_0

# %%
# !python --version
# Out:
# Python 3.9.12

# %%
# !git clone https://github.com/rasheedtobi/Blendmask_.git

# %%
# %cd Blendmask_
# Out:
# /home/rasheed_pf/new_test/Blendmask_

# %%
#To add AdelaiDet- dir for the main programs of the implementation- to rest of the content of my repo, clone inside . i.e insde my 
#Therefore , after cloning AdeilaiDet, The dir wehere 

# !git clone https://github.com/aim-uofa/AdelaiDet.git
# Out:
# Cloning into 'AdelaiDet'...
# remote: Enumerating objects: 2339, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 2339 (delta 5), reused 13 (delta 3), pack-reused 2317
# Receiving objects: 100% (2339/2339), 643.54 KiB | 1.62 MiB/s, done.
# Resolving deltas: 100% (1438/1438), done.

# %%
# %cd AdelaiDet/
# Out:
# /home/rasheed_pf/new_test/Blendmask_/AdelaiDet

# %%
# !python setup.py build develop
# Out:
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-39
# creating build/lib.linux-x86_64-cpython-39/adet
# copying adet/__init__.py -> build/lib.linux-x86_64-cpython-39/adet
# creating build/lib.linux-x86_64-cpython-39/adet/checkpoint
# copying adet/checkpoint/__init__.py -> build/lib.linux-x86_64-cpython-39/adet/checkpoint
# copying adet/checkpoint/adet_checkpoint.py -> build/lib.linux-x86_64-cpython-39/adet/checkpoint
# creating build/lib.linux-x86_64-cpython-39/adet/config
# copying adet/config/__init__.py -> build/lib.linux-x86_64-cpython-39/adet/config
# copying adet/config/defaults.py -> build/lib.linux-x86_64-cpython-39/adet/config
# copying adet/config/config.py -> build/lib.linux-x86_64-cpython-39/adet/config
# creating build/lib.linux-x86_64-cpython-39/adet/modeling
# copying adet/modeling/one_stage_detector.py -> build/lib.linux-x86_64-cpython-39/adet/modeling
# ...

# %%
import torch, detectron2

# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])

CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Wed_Jun__9_20:32:38_PDT_2021
# Cuda compilation tools, release 11.3, V11.3.122
# Build cuda_11.3.r11.3/compiler.30059648_0
# torch:  1.10 ; cuda:  cu113
# detectron2: 0.6

# %%
#To download the FCOS model to test our installation for Object Detection.
#The file can also be found in the seafile named 'fcos_R_50_1x.pth'

# !wget https://cloudstor.aarnet.edu.au/plus/s/glqFc13cCoEyHYy/download -O fcos_R_50_1x.pth
# Out:
# --2023-04-22 16:10:26--  https://cloudstor.aarnet.edu.au/plus/s/glqFc13cCoEyHYy/download
# Resolving cloudstor.aarnet.edu.au (cloudstor.aarnet.edu.au)... 202.158.207.20
# Connecting to cloudstor.aarnet.edu.au (cloudstor.aarnet.edu.au)|202.158.207.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: 5230042dc1897=eae14ac36jc5pg4khj2233adfj; path=/plus; domain=.aarnet.edu.au;; Secure; SameSite=Lax at position 76.
# Syntax error in Set-Cookie: oc_sessionPassphrase=S%2BX%2B4v4p%2FLbMCD75MjecLUMBO98MJ0acDIRBFZNKkBNEl3vnjXLOW9yuLV6zhUf4tGN50tTvQ3rYAo7STvL5pduaHpAj0WRl8BTfpMoTB9oBf7CFR0zy9mPltNG1oBHn; expires=Sun, 23-Apr-2023 14:10:26 GMT; Max-Age=86400; path=/plus;; Secure; SameSite=Lax at position 222.
# Length: 129471951 (123M) [application/octet-stream]
# Saving to: ‘fcos_R_50_1x.pth’
#
# fcos_R_50_1x.pth    100%[===================>] 123,47M  11,1MB/s    in 14s
#
# ...

# %%
# !python demo/demo.py \
    			--config-file configs/FCOS-Detection/R_50_1x.yaml \
    			--input input.jpg yes.jpeg \
    			--opts MODEL.WEIGHTS fcos_R_50_1x.pth
# Out:
# [04/22 16:22:51 detectron2]: Arguments: Namespace(config_file='configs/FCOS-Detection/R_50_1x.yaml', webcam=False, video_input=None, input=['input.jpg', 'yes.jpeg'], output=None, confidence_threshold=0.3, opts=['MODEL.WEIGHTS', 'fcos_R_50_1x.pth'])
# WARNING [04/22 16:22:51 d2.config.compat]: Config 'configs/FCOS-Detection/R_50_1x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# /home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...

# %%
#To download the BlendMask  model to test our installation for Instance Segmentation.
#The file can also be found in the seafile named 'blendmask_r101_dcni3_5x.pth'
#check new window in the taskbar to see predictions



# !wget -O blendmask_r101_dcni3_5x.pth https://cloudstor.aarnet.edu.au/plus/s/vbnKnQtaGlw8TKv/download #the model to make IS predictions on
# Out:
# --2023-04-22 16:30:46--  https://cloudstor.aarnet.edu.au/plus/s/vbnKnQtaGlw8TKv/download
# Resolving cloudstor.aarnet.edu.au (cloudstor.aarnet.edu.au)... 202.158.207.20
# Connecting to cloudstor.aarnet.edu.au (cloudstor.aarnet.edu.au)|202.158.207.20|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: 5230042dc1897=ea8fbb5deoh83lg8hjf05sib6b; path=/plus; domain=.aarnet.edu.au;; Secure; SameSite=Lax at position 76.
# Syntax error in Set-Cookie: oc_sessionPassphrase=CDhUcImJxN1GlY0EuN%2FWq4H8PibAX%2BCdCmtIVdlp2JVi5zFV5BqjCe1h8OiXEbMKZjIdNHZKaW6Jv9JGS45rTDIucULsYXSP7TvSKpsOuiyToLY7zNYs0cdJDO%2FnWKon; expires=Sun, 23-Apr-2023 14:30:47 GMT; Max-Age=86400; path=/plus;; Secure; SameSite=Lax at position 222.
# Length: 223398411 (213M) [application/octet-stream]
# Saving to: ‘blendmask_r101_dcni3_5x.pth’
#
# blendmask_r101_dcni 100%[===================>] 213,05M  11,1MB/s    in 22s
#
# ...

# %%
# !python demo/demo.py \
    			--config-file configs/BlendMask/R_101_dcni3_5x.yaml \
    			--input yes.jpeg \
    			--confidence-threshold 0.35 \
    			--opts MODEL.WEIGHTS blendmask_r101_dcni3_5x.pth
# Out:
# [04/22 16:41:27 detectron2]: Arguments: Namespace(config_file='configs/BlendMask/R_101_dcni3_5x.yaml', webcam=False, video_input=None, input=['yes.jpeg'], output=None, confidence_threshold=0.35, opts=['MODEL.WEIGHTS', 'blendmask_r101_dcni3_5x.pth'])
# WARNING [04/22 16:41:27 d2.config.compat]: Config 'configs/BlendMask/R_101_dcni3_5x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# /home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...

# %%
#demo_vacc.py can be found in the repo. copy and paste in AdelaiDet/demo
#The model can be found in seafile link with name 
#check new window in the taskbar to see predictions

# !python demo/demo_vacc.py \
		--config-file configs/BlendMask/R_50_1x.yaml \
    		--input 'vacc_plant.png'\
    		--confidence-threshold 0.3 \
	    	--opts MODEL.WEIGHTS training_dir/After_aug_blendmask_R_50_1x/model_final.pth
# Out:
# [04/23 02:36:36 detectron2]: Arguments: Namespace(config_file='configs/BlendMask/R_50_1x.yaml', webcam=False, video_input=None, input=['vacc_plant.png'], output=None, confidence_threshold=0.3, opts=['MODEL.WEIGHTS', 'training_dir/After_aug_blendmask_R_50_1x/model_final.pth'])
# WARNING [04/23 02:36:36 d2.config.compat]: Config 'configs/BlendMask/R_50_1x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# /home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2/structures/image_list.py:88: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   max_size = (max_size + (stride - 1)) // stride * stride
# ...

# %%
# !python datasets/prepare_thing_sem_from_instance.py
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Start writing to /home/rasheed_pf/new_test/Blendmask_/AdelaiDet/datasets/coco/thing_train2017 ...
# Finished. time: 4.04s

# %%
# !OMP_NUM_THREADS=1 python tools/train_net_vacc.py \
    --config-file configs/BlendMask/R_50_1x.yaml \
    --num-gpus 1 \
    OUTPUT_DIR training_dir/blendmask_R_50_1x
# Out:
# Command Line Args: Namespace(config_file='configs/BlendMask/R_50_1x.yaml', resume=False, eval_only=False, num_gpus=1, num_machines=1, machine_rank=0, dist_url='tcp://127.0.0.1:50162', opts=['OUTPUT_DIR', 'training_dir/blendmask_R_50_1x'])
# Config 'configs/BlendMask/R_50_1x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# [04/22 19:21:11 detectron2]: Rank of current process: 0. World size: 1
# [04/22 19:21:11 detectron2]: Environment info:
# ----------------------  -----------------------------------------------------------------------------------------------
# sys.platform            linux
# Python                  3.9.12 (main, Jun  1 2022, 11:38:51) [GCC 7.5.0]
# numpy                   1.23.0
# detectron2              0.6 @/home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2
# Compiler                GCC 7.3
# CUDA compiler           CUDA 11.3
# detectron2 arch flags   3.7, 5.0, 5.2, 6.0, 6.1, 7.0, 7.5, 8.0, 8.6
# ...

# %%
#To run just an evaluation on a model, use the syntax below.
#Here evaluation is run on the trained model  before final augmentation



# !OMP_NUM_THREADS=1 python tools/train_net_vacc.py \
    --config-file configs/BlendMask/R_50_1x.yaml \
    --eval-only \
    --num-gpus 1 \
    OUTPUT_DIR training_dir\
    MODEL.WEIGHTS training_dir/before_aug_blendmask_model/model_final.pth
# Out:
# Command Line Args: Namespace(config_file='configs/BlendMask/R_50_1x.yaml', resume=False, eval_only=True, num_gpus=1, num_machines=1, machine_rank=0, dist_url='tcp://127.0.0.1:50162', opts=['OUTPUT_DIR', 'training_dir', 'MODEL.WEIGHTS', 'training_dir/before_aug_blendmask_model/model_final.pth'])
# Config 'configs/BlendMask/R_50_1x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# [04/23 02:37:46 detectron2]: Rank of current process: 0. World size: 1
# [04/23 02:37:47 detectron2]: Environment info:
# ----------------------  -----------------------------------------------------------------------------------------------
# sys.platform            linux
# Python                  3.9.12 (main, Jun  1 2022, 11:38:51) [GCC 7.5.0]
# numpy                   1.23.0
# detectron2              0.6 @/home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2
# Compiler                GCC 7.3
# CUDA compiler           CUDA 11.3
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir training_dir/before_aug_blendmask_model
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-5b74231a79d21714" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5b74231a79d21714");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
#Here evaluation is run on the trained model  after final augmentation

# !OMP_NUM_THREADS=1 python tools/train_net_vacc.py \
    --config-file configs/BlendMask/R_50_1x.yaml \
    --eval-only \
    --num-gpus 1 \
    OUTPUT_DIR training_dir\
    MODEL.WEIGHTS training_dir/After_aug_blendmask_R_50_1x/model_final.pth
# Out:
# Command Line Args: Namespace(config_file='configs/BlendMask/R_50_1x.yaml', resume=False, eval_only=True, num_gpus=1, num_machines=1, machine_rank=0, dist_url='tcp://127.0.0.1:50162', opts=['OUTPUT_DIR', 'training_dir', 'MODEL.WEIGHTS', 'training_dir/After_aug_blendmask_R_50_1x/model_final.pth'])
# Config 'configs/BlendMask/R_50_1x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# [04/23 02:15:15 detectron2]: Rank of current process: 0. World size: 1
# [04/23 02:15:15 detectron2]: Environment info:
# ----------------------  -----------------------------------------------------------------------------------------------
# sys.platform            linux
# Python                  3.9.12 (main, Jun  1 2022, 11:38:51) [GCC 7.5.0]
# numpy                   1.23.0
# detectron2              0.6 @/home/rasheed_pf/.conda/envs/new_env_test/lib/python3.9/site-packages/detectron2
# Compiler                GCC 7.3
# CUDA compiler           CUDA 11.3
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir training_dir/After_aug_blendmask_R_50_1x
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-8dab20dc34af9659" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8dab20dc34af9659");
#           const url = new URL("/", window.location);
#           const port = 6009;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
